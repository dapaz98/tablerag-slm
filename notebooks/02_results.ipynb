# %%
import os
from pandas import pd

# Testar se consegue carregar uma tabela
table_path = os.path.join(
    "/home/eduardo-da-paz/Documents/master/tablerag-slm/results",
    "wtq_results.csv"
)   

table = pd.read_csv(table_path)
print(table.head())
print(f"Shape: {table.shape}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       4 # Testar se consegue carregar uma tabela
#       5 table_path = os.path.join(
#       6     "/home/eduardo-da-paz/Documents/master/tablerag-slm/results",
#       7     "wtq_results.csv"
#       8 )
# ---> 10 table = pd.read_csv(table_path)
#      11 print(table.head())
#      12 print(f"Shape: {table.shape}")
#
# AttributeError: 'function' object has no attribute 'read_csv'
